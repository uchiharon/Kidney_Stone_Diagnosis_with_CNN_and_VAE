# %% [markdown]
# # Testing the Classification model on just the test data

# %%
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
import math
import glob
import shutil
import cv2

# %%
reloaded = tf.keras.models.load_model('D:/uoc/KSD/Kidney_Stone_Diagnosis_with_CNN_and_VAE/Dataset/normal_image/normal_modelv1.h5')

# %%
# Access the training history
history = reloaded.history

# Print the training loss and metrics at each epoch
for epoch, loss, metric in zip(history.epoch, history.history['loss'], history.history['metric']):
    print(f"Epoch {epoch}: loss = {loss}, metric = {metric}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [3], line 5
#       2 history = reloaded.history
#       4 # Print the training loss and metrics at each epoch
# ----> 5 for epoch, loss, metric in zip(history.epoch, history.history['loss'], history.history['metric']):
#       6     print(f"Epoch {epoch}: loss = {loss}, metric = {metric}")
#
# AttributeError: 'NoneType' object has no attribute 'epoch'

# %%
help(reload)
# Out:
# Help on Sequential in module keras.engine.sequential object:
#
# class Sequential(keras.engine.functional.Functional)
#  |  Sequential(layers=None, name=None)
#  |
#  |  `Sequential` groups a linear stack of layers into a `tf.keras.Model`.
#  |
#  |  `Sequential` provides training and inference features on this model.
#  |
#  |  Examples:
#  |
#  |  ```python
#  |  # Optionally, the first layer can receive an `input_shape` argument:
#  |  model = tf.keras.Sequential()
#  |  model.add(tf.keras.layers.Dense(8, input_shape=(16,)))
#  |  # Afterwards, we do automatic shape inference:
#  |  model.add(tf.keras.layers.Dense(4))
#  |
#  |  # This is identical to the following:
#  |  model = tf.keras.Sequential()
#  |  model.add(tf.keras.Input(shape=(16,)))
#  |  model.add(tf.keras.layers.Dense(8))
#  |
#  |  # Note that you can also omit the `input_shape` argument.
#  |  # In that case the model doesn't have any weights until the first call
# ...

# %%
reload.output
# Out:
# <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'dense_1')>
